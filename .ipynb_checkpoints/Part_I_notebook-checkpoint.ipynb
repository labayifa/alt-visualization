# %% [markdown]
# # Part I - (Prosper Loan Dataset Exploration)
# ## by (Carmel Prosper SAGBO)
#
# ## Introduction
# > I choosed to work with Prosper Loan Data. This data set contain __113 937__ loan with 81 variables to describe each observation. Inside the dataset we have information about the borrower, the loan status, the loan amount, the income for each employee, among others.
#
# ###  Exploratory Goal
# > At first Step we will explore our dataset to understand then :
# >   - Select feature(s) of interest that we will use for the vizualization process
# >   - Select  features in the dataset that will help support our investigation into your feature(s) of interest
#
# > Our goal with this current work is to discover and explain
# >   - If Borrowers have been selected following right criteria,
# >   - And also being able to tell which group of people are holding the high risk by getting more loan.
# >   - If there is any other insight about a particular case of situation with borrower
# >   - If people really attend the payment of the loan
# ## Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# > Load in your dataset and describe its properties through the questions below. Try and motivate your exploration goals through this section.

# %%
df = pd.read_csv('prosperLoanData.csv')

# %% [markdown]
# ### What is the structure of your dataset?

# %%
# First we are trying to get information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 81 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   ListingKey                           113937 non-null  object
#  1   ListingNumber                        113937 non-null  int64
#  2   ListingCreationDate                  113937 non-null  object
#  3   CreditGrade                          28953 non-null   object
#  4   Term                                 113937 non-null  int64
#  5   LoanStatus                           113937 non-null  object
#  6   ClosedDate                           55089 non-null   object
#  7   BorrowerAPR                          113912 non-null  float64
#  8   BorrowerRate                         113937 non-null  float64
#  9   LenderYield                          113937 non-null  float64
#  10  EstimatedEffectiveYield              84853 non-null   float64
#  11  EstimatedLoss                        84853 non-null   float64
#  12  EstimatedReturn                      84853 non-null   float64
#  13  ProsperRating (numeric)              84853 non-null   float64
#  14  ProsperRating (Alpha)                84853 non-null   object
#  15  ProsperScore                         84853 non-null   float64
#  16  ListingCategory (numeric)            113937 non-null  int64
#  17  BorrowerState                        108422 non-null  object
#  18  Occupation                           110349 non-null  object
#  19  EmploymentStatus                     111682 non-null  object
#  20  EmploymentStatusDuration             106312 non-null  float64
#  21  IsBorrowerHomeowner                  113937 non-null  bool
#  22  CurrentlyInGroup                     113937 non-null  bool
#  23  GroupKey                             13341 non-null   object
#  24  DateCreditPulled                     113937 non-null  object
#  25  CreditScoreRangeLower                113346 non-null  float64
#  26  CreditScoreRangeUpper                113346 non-null  float64
#  27  FirstRecordedCreditLine              113240 non-null  object
#  28  CurrentCreditLines                   106333 non-null  float64
#  29  OpenCreditLines                      106333 non-null  float64
#  30  TotalCreditLinespast7years           113240 non-null  float64
#  31  OpenRevolvingAccounts                113937 non-null  int64
#  32  OpenRevolvingMonthlyPayment          113937 non-null  float64
#  33  InquiriesLast6Months                 113240 non-null  float64
#  34  TotalInquiries                       112778 non-null  float64
#  35  CurrentDelinquencies                 113240 non-null  float64
#  36  AmountDelinquent                     106315 non-null  float64
#  37  DelinquenciesLast7Years              112947 non-null  float64
#  38  PublicRecordsLast10Years             113240 non-null  float64
#  39  PublicRecordsLast12Months            106333 non-null  float64
#  40  RevolvingCreditBalance               106333 non-null  float64
#  41  BankcardUtilization                  106333 non-null  float64
#  42  AvailableBankcardCredit              106393 non-null  float64
#  43  TotalTrades                          106393 non-null  float64
#  44  TradesNeverDelinquent (percentage)   106393 non-null  float64
#  45  TradesOpenedLast6Months              106393 non-null  float64
#  46  DebtToIncomeRatio                    105383 non-null  float64
#  47  IncomeRange                          113937 non-null  object
#  48  IncomeVerifiable                     113937 non-null  bool
#  49  StatedMonthlyIncome                  113937 non-null  float64
#  50  LoanKey                              113937 non-null  object
#  51  TotalProsperLoans                    22085 non-null   float64
#  52  TotalProsperPaymentsBilled           22085 non-null   float64
#  53  OnTimeProsperPayments                22085 non-null   float64
#  54  ProsperPaymentsLessThanOneMonthLate  22085 non-null   float64
#  55  ProsperPaymentsOneMonthPlusLate      22085 non-null   float64
#  56  ProsperPrincipalBorrowed             22085 non-null   float64
#  57  ProsperPrincipalOutstanding          22085 non-null   float64
#  58  ScorexChangeAtTimeOfListing          18928 non-null   float64
#  59  LoanCurrentDaysDelinquent            113937 non-null  int64
#  60  LoanFirstDefaultedCycleNumber        16952 non-null   float64
#  61  LoanMonthsSinceOrigination           113937 non-null  int64
#  62  LoanNumber                           113937 non-null  int64
#  63  LoanOriginalAmount                   113937 non-null  int64
#  64  LoanOriginationDate                  113937 non-null  object
#  65  LoanOriginationQuarter               113937 non-null  object
#  66  MemberKey                            113937 non-null  object
#  67  MonthlyLoanPayment                   113937 non-null  float64
#  68  LP_CustomerPayments                  113937 non-null  float64
#  69  LP_CustomerPrincipalPayments         113937 non-null  float64
#  70  LP_InterestandFees                   113937 non-null  float64
#  71  LP_ServiceFees                       113937 non-null  float64
#  72  LP_CollectionFees                    113937 non-null  float64
#  73  LP_GrossPrincipalLoss                113937 non-null  float64
#  74  LP_NetPrincipalLoss                  113937 non-null  float64
#  75  LP_NonPrincipalRecoverypayments      113937 non-null  float64
#  76  PercentFunded                        113937 non-null  float64
#  77  Recommendations                      113937 non-null  int64
#  78  InvestmentFromFriendsCount           113937 non-null  int64
#  79  InvestmentFromFriendsAmount          113937 non-null  float64
#  80  Investors                            113937 non-null  int64
# dtypes: bool(3), float64(50), int64(11), object(17)
# memory usage: 68.1+ MB

# %% [markdown]
# #### With this huge number of observation we need to explore the dataset using a heatmap
# Let's then create a function to plot the heatmap for null values

# %%
"""
    heatmap_isna - Plot a heatmap with seaborn.
    df: The dataset used to make the plotting
"""
def heatmap_isna(df):
    plt.figure(figsize=(20,10))
    sns.heatmap(df.isna(), cbar=False)

# %%
# Ploting the heatmap help us to know much more about missing values
heatmap_isna(df)

# %%
# Now Looking at this result let us check the ratio of these missing values

# %%
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 300)
(df.isnull().sum()/len(df)*100).sort_values(ascending=False)
# Out:
# GroupKey                               88.290898
# LoanFirstDefaultedCycleNumber          85.121602
# ScorexChangeAtTimeOfListing            83.387311
# ProsperPrincipalOutstanding            80.616481
# ProsperPrincipalBorrowed               80.616481
# ProsperPaymentsOneMonthPlusLate        80.616481
# ProsperPaymentsLessThanOneMonthLate    80.616481
# OnTimeProsperPayments                  80.616481
# TotalProsperLoans                      80.616481
# TotalProsperPaymentsBilled             80.616481
# CreditGrade                            74.588588
# ClosedDate                             51.649596
# ProsperRating (Alpha)                  25.526387
# ProsperScore                           25.526387
# EstimatedReturn                        25.526387
# ProsperRating (numeric)                25.526387
# EstimatedLoss                          25.526387
# EstimatedEffectiveYield                25.526387
# DebtToIncomeRatio                       7.507658
# EmploymentStatusDuration                6.692295
# AmountDelinquent                        6.689662
# CurrentCreditLines                      6.673864
# BankcardUtilization                     6.673864
# PublicRecordsLast12Months               6.673864
# OpenCreditLines                         6.673864
# RevolvingCreditBalance                  6.673864
# TotalTrades                             6.621203
# TradesOpenedLast6Months                 6.621203
# TradesNeverDelinquent (percentage)      6.621203
# AvailableBankcardCredit                 6.621203
# BorrowerState                           4.840394
# Occupation                              3.149109
# EmploymentStatus                        1.979164
# TotalInquiries                          1.017229
# DelinquenciesLast7Years                 0.868901
# FirstRecordedCreditLine                 0.611742
# PublicRecordsLast10Years                0.611742
# TotalCreditLinespast7years              0.611742
# CurrentDelinquencies                    0.611742
# InquiriesLast6Months                    0.611742
# CreditScoreRangeUpper                   0.518708
# CreditScoreRangeLower                   0.518708
# BorrowerAPR                             0.021942
# LoanOriginalAmount                      0.000000
# InvestmentFromFriendsAmount             0.000000
# InvestmentFromFriendsCount              0.000000
# Recommendations                         0.000000
# PercentFunded                           0.000000
# LP_NonPrincipalRecoverypayments         0.000000
# LP_NetPrincipalLoss                     0.000000
# LP_CollectionFees                       0.000000
# LoanOriginationDate                     0.000000
# LP_GrossPrincipalLoss                   0.000000
# MemberKey                               0.000000
# MonthlyLoanPayment                      0.000000
# LP_ServiceFees                          0.000000
# LoanNumber                              0.000000
# LP_InterestandFees                      0.000000
# LP_CustomerPrincipalPayments            0.000000
# LP_CustomerPayments                     0.000000
# LoanOriginationQuarter                  0.000000
# ListingKey                              0.000000
# LoanMonthsSinceOrigination              0.000000
# CurrentlyInGroup                        0.000000
# ListingCreationDate                     0.000000
# Term                                    0.000000
# LoanStatus                              0.000000
# BorrowerRate                            0.000000
# LenderYield                             0.000000
# ListingCategory (numeric)               0.000000
# IsBorrowerHomeowner                     0.000000
# DateCreditPulled                        0.000000
# LoanCurrentDaysDelinquent               0.000000
# OpenRevolvingAccounts                   0.000000
# OpenRevolvingMonthlyPayment             0.000000
# ListingNumber                           0.000000
# IncomeRange                             0.000000
# IncomeVerifiable                        0.000000
# StatedMonthlyIncome                     0.000000
# LoanKey                                 0.000000
# Investors                               0.000000
# dtype: float64

# %%
# Let us have a quick look at missing ratio description
(df.isnull().sum()/len(df)*100).describe()
# Out:
# count    81.000000
# mean     14.780596
# std      27.954859
# min       0.000000
# 25%       0.000000
# 50%       0.518708
# 75%       6.689662
# max      88.290898
# dtype: float64

# %%
# We will extract from the dataset all columns that have less than 15 percent values null to reduce the dataset
df = df[df.columns[(df.isnull().sum()/len(df)*100) < 15 ]]
df.sample(5)
# Out:
#                      ListingKey  ListingNumber            ListingCreationDate  \
# 87623   A28035105662748842BF51B         497941  2011-03-14 09:48:34.380000000
# 18821   698234088526517234C47D2         256860  2007-12-28 10:48:13.927000000
# 104962  CF6F3540463901325C13D06         563577  2012-02-28 08:26:36.167000000
# 97689   FBCF356803919727225F7DF         696759  2013-01-09 16:23:19.083000000
# 41499   9FF63550060494112E37EBF         600357  2012-06-15 18:07:46.303000000
#
#         Term LoanStatus  BorrowerAPR  BorrowerRate  LenderYield  \
# 87623     36  Completed      0.35643        0.3199       0.3099
# 18821     36  Completed      0.26021        0.2450       0.2350
# 104962    60    Current      0.20358        0.1845       0.1745
# 97689     60  Completed      0.20081        0.1769       0.1669
# 41499     36    Current      0.28851        0.2499       0.2399
#
#         ListingCategory (numeric) BorrowerState    Occupation  \
# 87623                           7            PA  Professional
# 18821                           6            CA         Other
# 104962                          2            NY        Doctor
# 97689                           1            SC       Analyst
# 41499                           7            CO         Other
#
#        EmploymentStatus  EmploymentStatusDuration  IsBorrowerHomeowner  \
# 87623         Full-time                      41.0                False
# 18821         Full-time                      13.0                False
# 104962         Employed                      85.0                 True
# 97689          Employed                       2.0                False
# 41499             Other                      14.0                 True
#
#         CurrentlyInGroup               DateCreditPulled  \
# 87623              False            2011-03-14 09:48:26
# 18821               True  2007-12-18 11:46:28.497000000
# 104962             False            2012-02-28 08:26:31
# 97689              False            2013-02-12 09:58:27
# 41499              False            2012-06-15 18:07:42
#
#         CreditScoreRangeLower  CreditScoreRangeUpper FirstRecordedCreditLine  \
# 87623                   660.0                  679.0     1999-03-31 00:00:00
# 18821                   540.0                  559.0     1994-05-19 00:00:00
# 104962                  660.0                  679.0     1986-09-03 00:00:00
# 97689                   720.0                  739.0     1998-01-23 00:00:00
# 41499                   780.0                  799.0     1978-02-24 00:00:00
#
#         CurrentCreditLines  OpenCreditLines  TotalCreditLinespast7years  \
# 87623                 11.0             10.0                        30.0
# 18821                 10.0              8.0                        33.0
# 104962                11.0             12.0                        45.0
# 97689                 19.0             18.0                        50.0
# 41499                  6.0              5.0                        15.0
#
#         OpenRevolvingAccounts  OpenRevolvingMonthlyPayment  \
# 87623                       7                        567.0
# 18821                       6                        161.0
# 104962                      4                        354.0
# 97689                      19                        797.0
# 41499                       5                         59.0
#
#         InquiriesLast6Months  TotalInquiries  CurrentDelinquencies  \
# 87623                    0.0            13.0                   0.0
# 18821                    1.0             6.0                  19.0
# 104962                   0.0             4.0                   1.0
# 97689                    3.0             6.0                   0.0
# 41499                    0.0             0.0                   0.0
#
#         AmountDelinquent  DelinquenciesLast7Years  PublicRecordsLast10Years  \
# 87623                0.0                      0.0                       0.0
# 18821             3002.0                     54.0                       0.0
# 104962            3222.0                      5.0                       0.0
# 97689                0.0                      9.0                       0.0
# 41499                0.0                      0.0                       1.0
#
#         PublicRecordsLast12Months  RevolvingCreditBalance  \
# 87623                         0.0                 22240.0
# 18821                         0.0                  3529.0
# 104962                        0.0                 11078.0
# 97689                         0.0                 18003.0
# 41499                         0.0                   193.0
#
#         BankcardUtilization  AvailableBankcardCredit  TotalTrades  \
# 87623                  0.76                   6076.0         29.0
# 18821                  1.03                     41.0         19.0
# 104962                 0.77                   3222.0         19.0
# 97689                  0.37                  27052.0         50.0
# 41499                  0.00                    800.0         15.0
#
#         TradesNeverDelinquent (percentage)  TradesOpenedLast6Months  \
# 87623                                 1.00                      0.0
# 18821                                 0.29                      1.0
# 104962                                0.84                      1.0
# 97689                                 0.98                      3.0
# 41499                                 0.86                      0.0
#
#         DebtToIncomeRatio     IncomeRange  IncomeVerifiable  \
# 87623                0.22       $100,000+              True
# 18821                0.14  $50,000-74,999              True
# 104962               0.07       $100,000+              True
# 97689                0.19       $100,000+              True
# 41499                0.47       $1-24,999              True
#
#         StatedMonthlyIncome                  LoanKey  \
# 87623           8333.333333  C46B3614567091726F88C24
# 18821           5333.333333  4A17340973032789377F123
# 104962         23000.000000  4E463646108821993C8910E
# 97689          10000.000000  85463673883374782F6D828
# 41499           1562.000000  E6993653231520442963515
#
#         LoanCurrentDaysDelinquent  LoanMonthsSinceOrigination  LoanNumber  \
# 87623                           0                          36       47930
# 18821                           0                          74       24353
# 104962                          0                          24       62558
# 97689                           0                          13       85370
# 41499                           0                          21       68198
#
#         LoanOriginalAmount  LoanOriginationDate LoanOriginationQuarter  \
# 87623                 4000  2011-03-23 00:00:00                Q1 2011
# 18821                 3000  2008-01-04 00:00:00                Q1 2008
# 104962               15000  2012-03-27 00:00:00                Q1 2012
# 97689                16000  2013-02-15 00:00:00                Q1 2013
# 41499                 6000  2012-06-20 00:00:00                Q2 2012
#
#                       MemberKey  MonthlyLoanPayment  LP_CustomerPayments  \
# 87623   01653462234775048004C85              174.20              4643.24
# 18821   85233364939758404716C27               87.76              4281.37
# 104962  FEC13541016538699BC5DED              384.58              8845.34
# 97689   FBB435492258661126CF219              403.60             16201.61
# 41499   D67135503835242109FB6BF              238.53              4770.60
#
#         LP_CustomerPrincipalPayments  LP_InterestandFees  LP_ServiceFees  \
# 87623                        4125.29              517.95          -16.19
# 18821                        2999.99             1281.38          -52.29
# 104962                       4191.00             4654.34         -252.29
# 97689                       15999.99              201.62          -11.40
# 41499                        2777.30             1993.30          -79.78
#
#         LP_CollectionFees  LP_GrossPrincipalLoss  LP_NetPrincipalLoss  \
# 87623                 0.0                    0.0                  0.0
# 18821                 0.0                    0.0                  0.0
# 104962                0.0                    0.0                  0.0
# 97689                 0.0                    0.0                  0.0
# 41499                 0.0                    0.0                  0.0
#
#         LP_NonPrincipalRecoverypayments  PercentFunded  Recommendations  \
# 87623                               0.0            1.0                0
# 18821                               0.0            1.0                0
# 104962                              0.0            1.0                0
# 97689                               0.0            1.0                0
# 41499                               0.0            1.0                0
#
#         InvestmentFromFriendsCount  InvestmentFromFriendsAmount  Investors
# 87623                            0                          0.0         50
# 18821                            0                          0.0         47
# 104962                           0                          0.0        322
# 97689                            0                          0.0        186
# 41499                            0                          0.0          3

# %%
df.shape
# Out:
# (113937, 63)

# %%
heatmap_isna(df)

# %% [markdown]
# ## Now we will explore the 63 remain features that remain

# %%
for col in df.select_dtypes('int64'):
    print(f'{col :-<50}\n {df[col].describe()}\n')
# Out:
# ListingNumber-------------------------------------
#  count    1.139370e+05
# mean     6.278857e+05
# std      3.280762e+05
# min      4.000000e+00
# 25%      4.009190e+05
# 50%      6.005540e+05
# 75%      8.926340e+05
# max      1.255725e+06
# Name: ListingNumber, dtype: float64
#
# Term----------------------------------------------
#  count    113937.000000
# mean         40.830248
# std          10.436212
# min          12.000000
# 25%          36.000000
# 50%          36.000000
# 75%          36.000000
# max          60.000000
# Name: Term, dtype: float64
#
# ListingCategory (numeric)-------------------------
#  count    113937.000000
# mean          2.774209
# std           3.996797
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           3.000000
# max          20.000000
# Name: ListingCategory (numeric), dtype: float64
#
# OpenRevolvingAccounts-----------------------------
#  count    113937.00000
# mean          6.96979
# std           4.63097
# min           0.00000
# 25%           4.00000
# 50%           6.00000
# 75%           9.00000
# max          51.00000
# Name: OpenRevolvingAccounts, dtype: float64
#
# LoanCurrentDaysDelinquent-------------------------
#  count    113937.000000
# mean        152.816539
# std         466.320254
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        2704.000000
# Name: LoanCurrentDaysDelinquent, dtype: float64
#
# LoanMonthsSinceOrigination------------------------
#  count    113937.000000
# mean         31.896882
# std          29.974184
# min           0.000000
# 25%           6.000000
# 50%          21.000000
# 75%          65.000000
# max         100.000000
# Name: LoanMonthsSinceOrigination, dtype: float64
#
# LoanNumber----------------------------------------
#  count    113937.000000
# mean      69444.474271
# std       38930.479610
# min           1.000000
# 25%       37332.000000
# 50%       68599.000000
# 75%      101901.000000
# max      136486.000000
# Name: LoanNumber, dtype: float64
#
# LoanOriginalAmount--------------------------------
#  count    113937.00000
# mean       8337.01385
# std        6245.80058
# min        1000.00000
# 25%        4000.00000
# 50%        6500.00000
# 75%       12000.00000
# max       35000.00000
# Name: LoanOriginalAmount, dtype: float64
#
# Recommendations-----------------------------------
#  count    113937.000000
# mean          0.048027
# std           0.332353
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          39.000000
# Name: Recommendations, dtype: float64
#
# InvestmentFromFriendsCount------------------------
#  count    113937.000000
# mean          0.023460
# std           0.232412
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          33.000000
# Name: InvestmentFromFriendsCount, dtype: float64
#
# Investors-----------------------------------------
#  count    113937.000000
# mean         80.475228
# std         103.239020
# min           1.000000
# 25%           2.000000
# 50%          44.000000
# 75%         115.000000
# max        1189.000000
# Name: Investors, dtype: float64

# %%
for col in df.select_dtypes('float64'):
    print(f'{col :-<50}\n {df[col].describe()}\n')
# Out:
# BorrowerAPR---------------------------------------
#  count    113912.000000
# mean          0.218828
# std           0.080364
# min           0.006530
# 25%           0.156290
# 50%           0.209760
# 75%           0.283810
# max           0.512290
# Name: BorrowerAPR, dtype: float64
#
# BorrowerRate--------------------------------------
#  count    113937.000000
# mean          0.192764
# std           0.074818
# min           0.000000
# 25%           0.134000
# 50%           0.184000
# 75%           0.250000
# max           0.497500
# Name: BorrowerRate, dtype: float64
#
# LenderYield---------------------------------------
#  count    113937.000000
# mean          0.182701
# std           0.074516
# min          -0.010000
# 25%           0.124200
# 50%           0.173000
# 75%           0.240000
# max           0.492500
# Name: LenderYield, dtype: float64
#
# EmploymentStatusDuration--------------------------
#  count    106312.000000
# mean         96.071582
# std          94.480605
# min           0.000000
# 25%          26.000000
# 50%          67.000000
# 75%         137.000000
# max         755.000000
# Name: EmploymentStatusDuration, dtype: float64
#
# CreditScoreRangeLower-----------------------------
#  count    113346.000000
# mean        685.567731
# std          66.458275
# min           0.000000
# 25%         660.000000
# 50%         680.000000
# 75%         720.000000
# max         880.000000
# Name: CreditScoreRangeLower, dtype: float64
#
# CreditScoreRangeUpper-----------------------------
#  count    113346.000000
# mean        704.567731
# std          66.458275
# min          19.000000
# 25%         679.000000
# 50%         699.000000
# 75%         739.000000
# max         899.000000
# Name: CreditScoreRangeUpper, dtype: float64
#
# CurrentCreditLines--------------------------------
#  count    106333.000000
# mean         10.317192
# std           5.457866
# min           0.000000
# 25%           7.000000
# 50%          10.000000
# 75%          13.000000
# max          59.000000
# Name: CurrentCreditLines, dtype: float64
#
# OpenCreditLines-----------------------------------
#  count    106333.000000
# mean          9.260164
# std           5.022644
# min           0.000000
# 25%           6.000000
# 50%           9.000000
# 75%          12.000000
# max          54.000000
# Name: OpenCreditLines, dtype: float64
#
# TotalCreditLinespast7years------------------------
#  count    113240.000000
# mean         26.754539
# std          13.637871
# min           2.000000
# 25%          17.000000
# 50%          25.000000
# 75%          35.000000
# max         136.000000
# Name: TotalCreditLinespast7years, dtype: float64
#
# OpenRevolvingMonthlyPayment-----------------------
#  count    113937.000000
# mean        398.292161
# std         447.159711
# min           0.000000
# 25%         114.000000
# 50%         271.000000
# 75%         525.000000
# max       14985.000000
# Name: OpenRevolvingMonthlyPayment, dtype: float64
#
# InquiriesLast6Months------------------------------
#  count    113240.000000
# mean          1.435085
# std           2.437507
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max         105.000000
# Name: InquiriesLast6Months, dtype: float64
#
# TotalInquiries------------------------------------
#  count    112778.000000
# mean          5.584405
# std           6.429946
# min           0.000000
# 25%           2.000000
# 50%           4.000000
# 75%           7.000000
# max         379.000000
# Name: TotalInquiries, dtype: float64
#
# CurrentDelinquencies------------------------------
#  count    113240.000000
# mean          0.592052
# std           1.978707
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          83.000000
# Name: CurrentDelinquencies, dtype: float64
#
# AmountDelinquent----------------------------------
#  count    106315.000000
# mean        984.507059
# std        7158.270157
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      463881.000000
# Name: AmountDelinquent, dtype: float64
#
# DelinquenciesLast7Years---------------------------
#  count    112947.000000
# mean          4.154984
# std          10.160216
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max          99.000000
# Name: DelinquenciesLast7Years, dtype: float64
#
# PublicRecordsLast10Years--------------------------
#  count    113240.000000
# mean          0.312646
# std           0.727868
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          38.000000
# Name: PublicRecordsLast10Years, dtype: float64
#
# PublicRecordsLast12Months-------------------------
#  count    106333.000000
# mean          0.015094
# std           0.154092
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          20.000000
# Name: PublicRecordsLast12Months, dtype: float64
#
# RevolvingCreditBalance----------------------------
#  count    1.063330e+05
# mean     1.759871e+04
# std      3.293640e+04
# min      0.000000e+00
# 25%      3.121000e+03
# 50%      8.549000e+03
# 75%      1.952100e+04
# max      1.435667e+06
# Name: RevolvingCreditBalance, dtype: float64
#
# BankcardUtilization-------------------------------
#  count    106333.000000
# mean          0.561309
# std           0.317918
# min           0.000000
# 25%           0.310000
# 50%           0.600000
# 75%           0.840000
# max           5.950000
# Name: BankcardUtilization, dtype: float64
#
# AvailableBankcardCredit---------------------------
#  count    106393.000000
# mean      11210.225447
# std       19818.361309
# min           0.000000
# 25%         880.000000
# 50%        4100.000000
# 75%       13180.000000
# max      646285.000000
# Name: AvailableBankcardCredit, dtype: float64
#
# TotalTrades---------------------------------------
#  count    106393.000000
# mean         23.230034
# std          11.871311
# min           0.000000
# 25%          15.000000
# 50%          22.000000
# 75%          30.000000
# max         126.000000
# Name: TotalTrades, dtype: float64
#
# TradesNeverDelinquent (percentage)----------------
#  count    106393.000000
# mean          0.885897
# std           0.148179
# min           0.000000
# 25%           0.820000
# 50%           0.940000
# 75%           1.000000
# max           1.000000
# Name: TradesNeverDelinquent (percentage), dtype: float64
#
# TradesOpenedLast6Months---------------------------
#  count    106393.000000
# mean          0.802327
# std           1.097637
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max          20.000000
# Name: TradesOpenedLast6Months, dtype: float64
#
# DebtToIncomeRatio---------------------------------
#  count    105383.000000
# mean          0.275947
# std           0.551759
# min           0.000000
# 25%           0.140000
# 50%           0.220000
# 75%           0.320000
# max          10.010000
# Name: DebtToIncomeRatio, dtype: float64
#
# StatedMonthlyIncome-------------------------------
#  count    1.139370e+05
# mean     5.608026e+03
# std      7.478497e+03
# min      0.000000e+00
# 25%      3.200333e+03
# 50%      4.666667e+03
# 75%      6.825000e+03
# max      1.750003e+06
# Name: StatedMonthlyIncome, dtype: float64
#
# MonthlyLoanPayment--------------------------------
#  count    113937.000000
# mean        272.475783
# std         192.697812
# min           0.000000
# 25%         131.620000
# 50%         217.740000
# 75%         371.580000
# max        2251.510000
# Name: MonthlyLoanPayment, dtype: float64
#
# LP_CustomerPayments-------------------------------
#  count    113937.000000
# mean       4183.079489
# std        4790.907234
# min          -2.349900
# 25%        1005.760000
# 50%        2583.830000
# 75%        5548.400000
# max       40702.390000
# Name: LP_CustomerPayments, dtype: float64
#
# LP_CustomerPrincipalPayments----------------------
#  count    113937.000000
# mean       3105.536588
# std        4069.527670
# min           0.000000
# 25%         500.890000
# 50%        1587.500000
# 75%        4000.000000
# max       35000.000000
# Name: LP_CustomerPrincipalPayments, dtype: float64
#
# LP_InterestandFees--------------------------------
#  count    113937.000000
# mean       1077.542901
# std        1183.414168
# min          -2.349900
# 25%         274.870000
# 50%         700.840100
# 75%        1458.540000
# max       15617.030000
# Name: LP_InterestandFees, dtype: float64
#
# LP_ServiceFees------------------------------------
#  count    113937.000000
# mean        -54.725641
# std          60.675425
# min        -664.870000
# 25%         -73.180000
# 50%         -34.440000
# 75%         -13.920000
# max          32.060000
# Name: LP_ServiceFees, dtype: float64
#
# LP_CollectionFees---------------------------------
#  count    113937.000000
# mean        -14.242698
# std         109.232758
# min       -9274.750000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           0.000000
# Name: LP_CollectionFees, dtype: float64
#
# LP_GrossPrincipalLoss-----------------------------
#  count    113937.000000
# mean        700.446342
# std        2388.513831
# min         -94.200000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       25000.000000
# Name: LP_GrossPrincipalLoss, dtype: float64
#
# LP_NetPrincipalLoss-------------------------------
#  count    113937.000000
# mean        681.420499
# std        2357.167068
# min        -954.550000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       25000.000000
# Name: LP_NetPrincipalLoss, dtype: float64
#
# LP_NonPrincipalRecoverypayments-------------------
#  count    113937.000000
# mean         25.142686
# std         275.657937
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       21117.900000
# Name: LP_NonPrincipalRecoverypayments, dtype: float64
# PercentFunded-------------------------------------
#  count    113937.000000
# mean          0.998584
# std           0.017919
# min           0.700000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           1.012500
# Name: PercentFunded, dtype: float64
#
# InvestmentFromFriendsAmount-----------------------
#  count    113937.000000
# mean         16.550751
# std         294.545422
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       25000.000000
# Name: InvestmentFromFriendsAmount, dtype: float64

# %%
for col in df.select_dtypes('object'):
    print(f'{col :-<50}\n {df[col].describe()}\n')
# Out:
# ListingKey----------------------------------------
#  count                      113937
# unique                     113066
# top       17A93590655669644DB4C06
# freq                            6
# Name: ListingKey, dtype: object
#
# ListingCreationDate-------------------------------
#  count                            113937
# unique                           113064
# top       2013-10-02 17:20:16.550000000
# freq                                  6
# Name: ListingCreationDate, dtype: object
#
# LoanStatus----------------------------------------
#  count      113937
# unique         12
# top       Current
# freq        56576
# Name: LoanStatus, dtype: object
#
# BorrowerState-------------------------------------
#  count     108422
# unique        51
# top           CA
# freq       14717
# Name: BorrowerState, dtype: object
#
# Occupation----------------------------------------
#  count     110349
# unique        67
# top        Other
# freq       28617
# Name: Occupation, dtype: object
#
# EmploymentStatus----------------------------------
#  count       111682
# unique           8
# top       Employed
# freq         67322
# Name: EmploymentStatus, dtype: object
#
# DateCreditPulled----------------------------------
#  count                  113937
# unique                 112992
# top       2013-12-23 09:38:12
# freq                        6
# Name: DateCreditPulled, dtype: object
#
# FirstRecordedCreditLine---------------------------
#  count                  113240
# unique                  11585
# top       1993-12-01 00:00:00
# freq                      185
# Name: FirstRecordedCreditLine, dtype: object
#
# IncomeRange---------------------------------------
#  count             113937
# unique                 8
# top       $25,000-49,999
# freq               32192
# Name: IncomeRange, dtype: object
#
# LoanKey-------------------------------------------
#  count                      113937
# unique                     113066
# top       CB1B37030986463208432A1
# freq                            6
# Name: LoanKey, dtype: object
#
# LoanOriginationDate-------------------------------
#  count                  113937
# unique                   1873
# top       2014-01-22 00:00:00
# freq                      491
# Name: LoanOriginationDate, dtype: object
#
# LoanOriginationQuarter----------------------------
#  count      113937
# unique         33
# top       Q4 2013
# freq        14450
# Name: LoanOriginationQuarter, dtype: object
#
# MemberKey-----------------------------------------
#  count                      113937
# unique                      90831
# top       63CA34120866140639431C9
# freq                            9
# Name: MemberKey, dtype: object

# %%
for col in df.select_dtypes('bool'):
    print(f'{col :-<50}\n {df[col].unique()}\n')
# Out:
# IsBorrowerHomeowner-------------------------------
#  [ True False]
#
# CurrentlyInGroup----------------------------------
#  [ True False]
#
# IncomeVerifiable----------------------------------
#  [ True False]

# %%
# The
df_main = df[['IsBorrowerHomeowner', 'IncomeVerifiable','IncomeRange', 'LoanStatus', 'Occupation', 'EmploymentStatus', 'LoanOriginalAmount','BorrowerRate','EmploymentStatusDuration', 'DebtToIncomeRatio','MonthlyLoanPayment', 'TotalCreditLinespast7years', 'DelinquenciesLast7Years']]

# %% [markdown]
# ### What is/are the main feature(s) of interest in your dataset?
#
# > __IsBorrowerHomeowner__ : A Borrower will be classified as a homowner if they have a mortgage on their credit profile or provide documentation confirming they are a homeowner.
#
# > __IncomeVerifiable__ : The borrower indicated they have the required documentation to support their income.
#
# > __IncomeRange__ : The income range of the borrower at the time the listing was created.
#
# > __LoanStatus__ : The current status of the loan: Cancelled,  Chargedoff, Completed, Current, Defaulted, FinalPaymentInProgress, PastDue. The PastDue status will be accompanied by a delinquency bucket.
#
# > __Occupation__ : The Occupation selected by the Borrower at the time they created the listing.
#
# > __EmploymentStatus__ : The employment status of the borrower at the time they posted the listing.
#
# > __LoanOriginalAmount__ : The origination amount of the loan.
#
# > __BorrowerRate__ : The Borrower's interest rate for this loan.
#
# > __EmploymentStatusDuration__ : EmploymentStatusDuration
#
# > __DebtToIncomeRatio__ : The debt to income ratio of the borrower at the time the credit profile was pulled. This value is Null if the debt to income ratio is not available. This value is capped at 10.01 (any debt to income ratio larger than 1000% will be returned as 1001%).
#
# > __MonthlyLoanPayment__ : The scheduled monthly loan payment.
#
# > __TotalCreditLinespast7years__ : Number of credit lines in the past seven years at the time the credit profile was pulled.
#
# > __DelinquenciesLast7Years__ : Number of delinquencies in the past 7 years at the time the credit profile was pulled.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > __LoanStatus__ : The current status of the loan: Cancelled,  Chargedoff, Completed, Current, Defaulted, FinalPaymentInProgress, PastDue. The PastDue status will be accompanied by a delinquency bucket.
#
# > __Occupation__ : The Occupation selected by the Borrower at the time they created the listing.
#
# > __LoanOriginalAmount__ : The origination amount of the loan.
#
# > __MonthlyLoanPayment__ : The scheduled monthly loan payment.

# %%
df_main.sample(5)
# Out:
#        IsBorrowerHomeowner  IncomeVerifiable     IncomeRange  LoanStatus  \
# 35587                 True              True       $100,000+     Current
# 83557                 True              True  $50,000-74,999     Current
# 62006                 True              True       $100,000+     Current
# 7339                  True              True  $50,000-74,999   Completed
# 93226                 True              True       $100,000+  Chargedoff
#
#           Occupation EmploymentStatus  LoanOriginalAmount  BorrowerRate  \
# 35587  Civil Service         Employed                4000        0.3073
# 83557          Other         Employed               15000        0.2468
# 62006      Executive         Employed               15000        0.1396
# 7339    Professional         Employed                8000        0.1902
# 93226   Food Service    Self-employed               25000        0.1400
#
#        EmploymentStatusDuration  DebtToIncomeRatio  MonthlyLoanPayment  \
# 35587                     292.0               0.25              171.41
# 83557                       5.0               0.37              437.46
# 62006                     115.0               0.17              348.71
# 7339                      384.0               0.29              293.33
# 93226                      63.0               0.10              854.44
#
#        TotalCreditLinespast7years  DelinquenciesLast7Years
# 35587                        45.0                     16.0
# 83557                        20.0                      0.0
# 62006                        46.0                      0.0
# 7339                         38.0                      4.0
# 93226                        12.0                      0.0

# %%
df_main.describe()
# Out:
#        LoanOriginalAmount   BorrowerRate  EmploymentStatusDuration  \
# count        113937.00000  113937.000000             106312.000000
# mean           8337.01385       0.192764                 96.071582
# std            6245.80058       0.074818                 94.480605
# min            1000.00000       0.000000                  0.000000
# 25%            4000.00000       0.134000                 26.000000
# 50%            6500.00000       0.184000                 67.000000
# 75%           12000.00000       0.250000                137.000000
# max           35000.00000       0.497500                755.000000
#
#        DebtToIncomeRatio  MonthlyLoanPayment  TotalCreditLinespast7years  \
# count      105383.000000       113937.000000               113240.000000
# mean            0.275947          272.475783                   26.754539
# std             0.551759          192.697812                   13.637871
# min             0.000000            0.000000                    2.000000
# 25%             0.140000          131.620000                   17.000000
# 50%             0.220000          217.740000                   25.000000
# 75%             0.320000          371.580000                   35.000000
# max            10.010000         2251.510000                  136.000000
#
#        DelinquenciesLast7Years
# count            112947.000000
# mean                  4.154984
# std                  10.160216
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   3.000000
# max                  99.000000

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   IsBorrowerHomeowner         113937 non-null  bool
#  1   IncomeVerifiable            113937 non-null  bool
#  2   IncomeRange                 113937 non-null  object
#  3   LoanStatus                  113937 non-null  object
#  4   Occupation                  110349 non-null  object
#  5   EmploymentStatus            111682 non-null  object
#  6   LoanOriginalAmount          113937 non-null  int64
#  7   BorrowerRate                113937 non-null  float64
#  8   EmploymentStatusDuration    106312 non-null  float64
#  9   DebtToIncomeRatio           105383 non-null  float64
#  10  MonthlyLoanPayment          113937 non-null  float64
#  11  TotalCreditLinespast7years  113240 non-null  float64
#  12  DelinquenciesLast7Years     112947 non-null  float64
# dtypes: bool(2), float64(6), int64(1), object(4)
# memory usage: 9.8+ MB

# %% [markdown]
# ## Univariate Exploration
#
# > Exploration of our dataset using visualization

# %% [markdown]
# #### Question 1: Is Borrower Home owner ?

# %% [markdown]
# #### Visualization 1

# %%
plt.figure(figsize=(10,8))
df_main.IsBorrowerHomeowner.value_counts().plot(kind='bar')
plt.title('Borrower Home Owned')
plt.xlabel('value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Observation 1:
# > Arround __50%__ percent of all loan have the Borrower as the owner of their house. In future exploration we will see if there is realation between this variable and the loan amount

# %% [markdown]
# #### Question 2 : Did all  borrowers have their Income Verifiable

# %% [markdown]
# #### Visualization 2

# %%
sns.countplot(data= df_main, x = 'IncomeVerifiable').set_title('Income verifiable')
plt.show()
# Explore false group

# %% [markdown]
# #### Observation 2:
# > Most of loans are recorded to people with income verifiable. We should discuss later about the case of people without verifiable income.

# %% [markdown]
# #### Question 3 : What are the distribution of Borrower Income Range ?

# %%
df_main.IncomeRange.value_counts()
# Out:
# $25,000-49,999    32192
# $50,000-74,999    31050
# $100,000+         17337
# $75,000-99,999    16916
# Not displayed      7741
# $1-24,999          7274
# Not employed        806
# $0                  621
# Name: IncomeRange, dtype: int64

# %%
df_main.IncomeRange.value_counts().index
# Out:
# Index(['$25,000-49,999', '$50,000-74,999', '$100,000+', '$75,000-99,999',
#        'Not displayed', '$1-24,999', 'Not employed', '$0'],
#       dtype='object')

# %% [markdown]
# #### Visualization 3

# %%
order_income_range = ['Not employed', '$0','$1-24,999','$25,000-49,999', '$50,000-74,999', '$75,000-99,999', '$100,000+', 'Not displayed']
plt.figure(figsize=(10,8))
sns.countplot(data= df_main, x = 'IncomeRange', order= order_income_range).set_title('Income range')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Observation 3:
# > The highest  amount or number of loans are for people with salary greather or equal to __25,000__.

# %% [markdown]
# #### Question 4: Did Borrower keep their engagement by paying ?
# > Loan Status Exploration

# %% [markdown]
# #### Visualization 4

# %%
colors =  sns.color_palette()[0]
loan_status_orders = df_main.LoanStatus.value_counts().index
sns.countplot(data= df_main, y = 'LoanStatus', color= colors, order=loan_status_orders).set_title('Loan status')
plt.show()

# %% [markdown]
# #### Observation 4:
# > There is barely any past due. We can conclude that Prosper Employees has doing great Job in Borrower selection.

# %% [markdown]
# ### Question 5: What is the distribution of Borrower Occupation ?

# %% [markdown]
# ###### Other
# > [nan, 'Other']
#
#
# ###### Religious
# > ['Religious', 'Clergy', 'Clerical'],
#
#
# ###### Food And Services
# > ['Food Service Management', 'Food Service', 'Social Worker', 'Waiter/Waitress']
#
#
# ###### Health And Science
#
# > ['Scientist', 'Psychologist', 'Biologist', 'Chemist', 'Dentist', 'Doctor', 'Pharmacist', 'Medical Technician', 'Nurse (RN)',  "Nurse's Aide",  'Nurse (LPN)']
#
#
# ##### Economy
# > ['Pilot - Private/Commercial',  'Retail Management', 'Sales - Commission', 'Car Dealer', 'Attorney', 'Accountant/CPA', 'Investor']
#
#
# ###### Professional And Enginneering
# > ['Engineer - Electrical', 'Architect', 'Engineer - Mechanical',  'Engineer - Chemical', 'Construction', 'Landscaping', 'Professional', 'Computer Programmer', 'Analyst']
#
#
# ###### Laborer
# > ['Tradesman - Plumber', 'Tradesman - Carpenter', 'Tradesman - Electrician', 'Laborer', 'Skilled Labor', 'Tradesman - Mechanic', 'Homemaker',  'Truck Driver', 'Bus Driver']
#
#
# ###### Administrative
# > ['Civil Service', 'Executive', 'Administrative Assistant',  'Postal Service', 'Military Enlisted', 'Judge',  'Police Officer/Correction Officer', 'Military Officer',  'Flight Attendant', 'Fireman', 'Realtor']
#
#
# ######  School Head
# > ['Principal', "Teacher's Aide",  'Professor', 'Teacher']
#
# ###### Students
# >['Student - College Senior','Student - College Junior', 'Student - College Graduate Student', 'Student - Technical School',  'Student - Community College', 'Student - College Freshman', 'Student - College Sophomore']

# %%
""" Create Occupation Group with existing Occupation in a dataset"""
def occupation_group(df):
    if df['Occupation'] in['Food Service Management', 'Food Service', 'Social Worker', 'Waiter/Waitress']:
        return 'Food And Services'
    elif df['Occupation'] in['Scientist', 'Psychologist', 'Biologist', 'Chemist', 'Dentist', 'Doctor', 'Pharmacist', 'Medical Technician', 'Nurse (RN)',  "Nurse's Aide",  'Nurse (LPN)']:
        return 'Health And Science'
    elif df['Occupation'] in ['Pilot - Private/Commercial',  'Retail Management', 'Sales - Commission', 'Car Dealer', 'Attorney', 'Accountant/CPA', 'Investor']:
        return 'Economy'
    elif df['Occupation'] in ['Engineer - Electrical', 'Architect', 'Engineer - Mechanical',  'Engineer - Chemical', 'Construction', 'Landscaping', 'Professional', 'Computer Programmer', 'Analyst']:
        return 'Professional And Enginneering'
    elif df['Occupation'] in ['Tradesman - Plumber', 'Tradesman - Carpenter', 'Tradesman - Electrician', 'Laborer', 'Skilled Labor', 'Tradesman - Mechanic', 'Homemaker',  'Truck Driver', 'Bus Driver']:
        return 'Laborer'
    elif df['Occupation'] in ['Civil Service', 'Executive', 'Administrative Assistant',  'Postal Service', 'Military Enlisted', 'Judge',  'Police Officer/Correction Officer', 'Military Officer',  'Flight Attendant', 'Fireman', 'Realtor']:
        return 'Administrative'
    elif df['Occupation'] in ['Principal', "Teacher's Aide",  'Professor', 'Teacher']:
        return 'School Head'
    elif df['Occupation'] in ['Student - College Senior','Student - College Junior', 'Student - College Graduate Student', 'Student - Technical School',  'Student - Community College', 'Student - College Freshman', 'Student - College Sophomore']:
        return 'School Head'
    elif df['Occupation'] in ['Religious', 'Clergy', 'Clerical']:
        return 'Religious'
    else:
        return 'Other' 
    
df_main['OccuGroup'] = df_main.apply(occupation_group, axis=1)
df_main['OccuGroup'].value_counts()
# Out:
# /tmp/ipykernel_6279/3501463599.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main['OccuGroup'] = df_main.apply(occupation_group, axis=1)
# Other                            35002
# Professional And Enginneering    26703
# Administrative                   14389
# Economy                          10920
# Laborer                           8102
# Health And Science                6195
# School Head                       5603
# Food And Services                 3539
# Religious                         3484
# Name: OccuGroup, dtype: int64

# %% [markdown]
# #### Visualization 5

# %%
plt.figure(figsize=(10,8))
df_main[df_main.OccuGroup != "Other"]['OccuGroup'].value_counts().plot(kind='pie', autopct='%.0f%%')
plt.title('Occupation Group Ratio')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# #### Observation 5:
# > With the Occupation variable we have many occupation, so to able to have a view through it we change it to group of ocuppation. Like that we are able to get an observation and most of loans have known jobs classified in groups above. Engineers are the most getting loans.

# %% [markdown]
# #### Question 6 : Are all our Borrowers in good situation with their Employment Status ?

# %% [markdown]
# #### Visualization 6

# %%
colors = sns.color_palette()[0]
employment_status_orders = df_main.EmploymentStatus.value_counts().index
sns.countplot(data= df_main, y = 'EmploymentStatus', color= colors, order=employment_status_orders).set_title('Employment status')
plt.show()

# %% [markdown]
# #### Observation 6:
# > The Borrowers are either employed or self employed

# %% [markdown]
# #### Question 7 What distribution is the Loan Original Amount following

# %% [markdown]
# #### Visualization 7

# %%
plt.figure(figsize=(10,8))
plt.hist(df_main.LoanOriginalAmount, color='r', bins=7)
plt.title('Loan Original Amount')
plt.show()

# %% [markdown]
# #### Observation 7:
# > Observing the distribution of loans amount we can say that the loan hug less risk. Only few persons have huge loan.

# %% [markdown]
# #### Question 8 Is the Loan company getting good income based on the BorrowerRate

# %% [markdown]
# #### Visualization 8

# %%
df_main.BorrowerRate.describe()
# Out:
# count    113937.000000
# mean          0.192764
# std           0.074818
# min           0.000000
# 25%           0.134000
# 50%           0.184000
# 75%           0.250000
# max           0.497500
# Name: BorrowerRate, dtype: float64

# %%
df_main.BorrowerRate.hist()
plt.title('Borrower Rate')
plt.show()

# %% [markdown]
# #### Observation 8:
# > The borrower rate often between 5% and 40%. But we also have a specific case of 50%

# %% [markdown]
# #### Question 9: Read the Employment Status Duration distribution in month?

# %% [markdown]
# #### Visualization 9

# %%
# sns.countplot(data= df_main, x = 'EmploymentStatusDuration', color= colors)
df_main.EmploymentStatusDuration.hist()
plt.title('Employment Status Duration in month')
plt.show()

# %% [markdown]
# #### Observation 9:
# > Every loan follow the condition that the Borrower have an employment status for duration that helps cover some risks

# %% [markdown]
# #### DebtToIncomeRatio

# %%
df_main.DebtToIncomeRatio.sort_values(ascending=False)
# Out:
# 60894     10.01
# 59733     10.01
# 70843     10.01
# 20524     10.01
# 113626    10.01
#           ...
# 113893      NaN
# 113894      NaN
# 113899      NaN
# 113903      NaN
# 113908      NaN
# Name: DebtToIncomeRatio, Length: 113937, dtype: float64

# %% [markdown]
# #### Question 10 : what are the company getting as Monthly Loan Payment.

# %% [markdown]
# #### Visualization 10

# %%
plt.figure(figsize=(10,8))
plt.hist(df_main.MonthlyLoanPayment, color='r', bins = 10)
plt.show()

# %% [markdown]
# #### Observation 10:
# > Borrower should pay each month at least 100

# %% [markdown]
# #### Question 11 : Are they giving loan to people with existing Credit Lines during the past 7 years ?

# %% [markdown]
# #### Visualization 11

# %%
df_main.TotalCreditLinespast7years.hist(bins=7)
plt.title('Total Credit Lines past 7 years')
plt.show()

# %% [markdown]
# #### Observation 11:
# > The borrowers are people known with certains number of credit so, with some rate of trust.

# %% [markdown]
# ####  Question 12 : Is there an error giving loan to people with high rate of delinquencies during the last   7 Years ?

# %% [markdown]
# #### Visualization 12

# %%
df_main.DelinquenciesLast7Years.hist(bins=15)
plt.title('Delinquencies Last 7 Years')
plt.show()

# %% [markdown]
# #### Observation 12:
# > All loans are given following the lowest number of delinquencies

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > We have registered three variables of interest: Means __Occupation, LoanOriginalAmount and MonthlyLoanPayment__.
#   During our exploration we have found that most of 69% of all our dataset have known and classified work as Occupation, And to be able to get this information we transformed Occupation into group. Now to get more about the relation let's dive into some observations with Bivariate exploratio and possible multivariate to get a better understand.
#
# > The Prosper Loan company really care about the delinquencies, and trust also people that already have a number of existing Credit line.
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > With our exploration, there were some difficulty with salary range  for plotting resolved by using custum order when plotting. we have also perfomed a new column named __OccuGroup__ for __Occupation__ in order to appreciate the distribution of loan among all group or class of Borrower.

# %%
### For the remains analysys we are changing the dataset to look only for those with known Occupation
df_main = df_main[df_main.OccuGroup != "Other"]

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# #### Question 1: How does evolve the loan based on the Occupation Group of Borrowers

# %% [markdown]
# #### Visualization 1:

# %%
# df_main.groupby('OccuGroup').LoanOriginalAmount.hist()
plt.figure(figsize=(10,8))
sns.lineplot(x=df_main.OccuGroup, y=df_main.LoanOriginalAmount, palette=colors)
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# #### Observation 1:
# > The most in demand and highest group in need of loans are : (Health And Science, Professional And Engineering)

# %% [markdown]
# #### Question 2 : Did Borrower paying enough to company cover lost found based on Interest

# %% [markdown]
# #### Visualization 2

# %%
# colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(10,8))
# sns.scatterplot(x=df_main.LoanOriginalAmount, y=df_main.MonthlyLoanPayment)
sns.scatterplot(data = df_main, x = 'LoanOriginalAmount', y = 'BorrowerRate').set_title('Loan Amount according to Borrower Rate') 
plt.show()

# %% [markdown]
# #### Observation 2:
# > The Highest the loan is, the Borrower rate decrease. Prosper ensure they are getting best interest rate to cover any futher lost from those who cannot pay

# %% [markdown]
# #### Question 3:

# %% [markdown]
# #### Visualization 3

# %%
# colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(10,8))
# sns.scatterplot(x=df_main.LoanOriginalAmount, y=df_main.MonthlyLoanPayment)
sns.regplot(data = df_main, x = 'LoanOriginalAmount', y = 'MonthlyLoanPayment').set_title('Monthly Loan Payment and Loan Amount') 
plt.show()

# %% [markdown]
# #### Question 4: Following the Loan Original Amount based on Occupation what group of people have high demand impact as Borrower ?

# %% [markdown]
# #### Visualization 4

# %%
plt.figure(figsize=(10,8))
base_color = sns.color_palette()[0]
sns.boxplot(data=df_main, y='LoanOriginalAmount', x='OccuGroup', color=base_color).set_title('Loan Original Amount based on Occupation')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# #### Observation 4:
# > The most in demand and highest group in need of loans are : (Health And Science, Professional And Engineering)

# %%
df_false = df_main[df_main.IncomeVerifiable == False].groupby(['EmploymentStatus']).IsBorrowerHomeowner.value_counts()
df_false
# Out:
# EmploymentStatus  IsBorrowerHomeowner
# Employed          False                   681
#                   True                    333
# Full-time         False                   288
#                   True                    227
# Not available     False                    24
#                   True                     11
# Not employed      False                    18
#                   True                      3
# Part-time         False                    69
#                   True                     13
# Retired           False                     3
# Self-employed     False                  1735
#                   True                   1471
# Name: IsBorrowerHomeowner, dtype: int64

# %%
order_income_range = ['Not displayed', '$1-24,999','$25,000-49,999', '$50,000-74,999', '$75,000-99,999', '$100,000+']
plt.figure(figsize=(10,8))
sns.countplot(data= df_main, x = 'IncomeRange', hue='OccuGroup', order= order_income_range).set_title('Income range')
plt.xticks(rotation=90)
plt.show()
# Ordorner le graphique

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df_main, x='IncomeRange', y='MonthlyLoanPayment', color= base_color,order= order_income_range) 
plt.xticks(rotation=15);
plt.ylabel('Avg Monthly Loan Payment')
plt.show()

# %% [markdown]
# #### Oservation 5:
# > As the income range is growing, the average value on monthly is growing. So nothing really critical to observe.
#  We can just say that it is a normal pattern for their loan.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > During this evaluation through bivariate exploration we  can see that the monthly loan payment increase depending on the salary range.  Also Health, Science, Professional And Engineering group persons are requesting more loans than others group.
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > A Quick observation of people without verifiable income are not really those owning home. Is there any specific reason explaining the loan attributed to people without income verifiable ?
# Is Delinquencies Last 7 Years not valuable for them.

# %% [markdown]
# ## Multivariate Exploration
# > In this section will try to undestand the relation between our main features

# %% [markdown]
# #### Question 1 : What is the delinquencies impact for no income verifiable on loan

# %% [markdown]
# #### Visualization

# %%
plt.figure(figsize=(10,10))
g = sns.PairGrid(data = df_main[df_main.IncomeVerifiable == False], vars = ['MonthlyLoanPayment', 'LoanOriginalAmount', 'DelinquenciesLast7Years'])
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
plt.xticks(rotation=90);
plt.title('Delinquencies impact for no income verifiable on loan', loc= 'center', pad =200)
plt.show()

# %% [markdown]
# #### Observation 1:
# > All the graphics are following the same pattern as with all entries from the dataset.
# So can not yet conclude why this specific group of people are getting the loan.

# %% [markdown]
# #### Question 2: Based on the Borrower, let's explore if Loan payment is good for Prosper Company ?

# %% [markdown]
# #### Visualisation 2

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data = df_main, x = 'LoanOriginalAmount', y = 'MonthlyLoanPayment', c = 'BorrowerRate')
plt.colorbar()
plt.title('Loan distribution on interest rate')
plt.show()

# %% [markdown]
# #### Oservation 2:
# > The interest are concentrate around 3% to 40% per month. This help to secure the loan payment got from Borrower.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Overall our exploration there the loan is attribute to people following their group, the income range. They also take of everything to avoid loast for the company. Like that, the Borrower following his salary range pay their monthly loan accodingly.
#
# ### Were there any interesting or surprising interactions between features?
#
# > There is not really something specific explaining the loan for people without income verifiable. We might later explore other variable to correctly this specific choice four this group of Borrowers.

# %% [markdown]
# ## Conclusions
# #### Step 1 :
#
# > Prosper Loan Data set contain 113 937 loan with 81 variables to describe each observation about the borrower, the loan. Because of the large number of variable that we have, my first thougth was to sort the relation between all varaible to see if we are in case of merged dataset or informatio from different source. By following this exploration I found that we some variables have more thant __25%__ of their values null.
#
# #### Step 2 :
# > Second step we remove theses unuseful variables, then explore again variable type by type and choosed now 12 variables from all the dataset.
# #### Step 3:
# > Now we have proceed with univariate, bivariate and multivariate exploration and finally get which group of people demanding the most and highest loans, and also what is their salary range.
# But Something bizarre actually is that we did not understand why people without income veriable have gotten loan.
# Finally the teams working to select Borrowers are doing great job.
